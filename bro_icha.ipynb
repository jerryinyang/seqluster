# %%
data.columns
# Out:
# Index(['Timestamp', 'Username', 'QUESTIONNAIRE CONSENT FORM', '1. Gender',
#        '2. Age Range in Years', '3. Marital Status', '4. Religion ',
#        '5. Education Level', '6. Country  of Residence ',
#        '7. How would you rate your overall knowledge about malaria prevention? ',
#        '8. Where did you get information about malaria? ',
#        '9. Have you or someone you know ever had malaria? ',
#        '10. Which of the following is implicated in malaria transmission? ',
#        '11. Can malaria infection be prevented? ',
#        '12. Which of the following may be used in malaria prevention? Select as many as apply.  ',
#        '13. How should malaria prevention be advertised to improve awareness? Select as many as apply.  ',
#        '14.  How often do you use ‘Insecticide-Treated Nets (ITNs)’ in your household? ',
#        '15. How effective do you think ‘Insecticide-Treated Nets (ITNs)’ are, in preventing malaria? ',
# ...

# %%
clean_data.head(2)
# Out:
#   1. Gender 2. Age Range in Years 3. Marital Status  4. Religion   \
# 0      MALE               30 - 39            SINGLE  Christianity
# 1    Female               20 - 29            Single  Christianity
#
#   5. Education Level 6. Country  of Residence   \
# 0           Tertiary                   Nigeria
# 1           Tertiary                   Nigeria
#
#   7. How would you rate your overall knowledge about malaria prevention?   \
# 0                                          Very High
# 1                                               High
#
#   8. Where did you get information about malaria?   \
# 0                          Healthcare Professional
# 1                          Healthcare Professional
#
#   9. Have you or someone you know ever had malaria?   \
# 0                                                Yes
# 1                                                Yes
#
#   10. Which of the following is implicated in malaria transmission?   ...  \
# ...

# %%
# Out:
# 1. Gender
# Male      116
# Female     92
# MALE        1
# Name: count, dtype: int64
# 2. Age Range in Years
# 20 - 29    89
# 30 - 39    77
# 40 - 49    29
# <20         8
# >50         6
# Name: count, dtype: int64
# 3. Marital Status
# Single     126
# Married     81
# SINGLE       1
# Widower      1
# Name: count, dtype: int64
# 4. Religion
# Christianity            186
# Islam                    21
# Eckankar                  1
# Traditional religion      1
# Name: count, dtype: int64
# 5. Education Level
# Tertiary              201
# Secondary               6
# Informal Education      2
# Name: count, dtype: int64
# 6. Country  of Residence
# Nigeria    209
# Name: count, dtype: int64
# 7. How would you rate your overall knowledge about malaria prevention?
# High         91
# Moderate     63
# Very High    47
# Low           6
# Very Low      1
# Not Sure      1
# Name: count, dtype: int64
# 8. Where did you get information about malaria?
# ...
